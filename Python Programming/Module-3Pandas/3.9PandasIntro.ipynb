# %%
#PANDAS...
#an opensource library built on top of NumPy..
#Name from PANel DAta System --> PANDAS... BY Wes McKinney...
#Load Data in DATAFRAMES a 2D DataStructure (sql table) with heterogeneous data cols having both ROW & COL Indexes...

import pandas as pd

# %%
pd.__version__
# Out:
# '1.4.4'

# %%
#READ DATASETS IN PANDAS DATFRAME....
df_titanic=pd.read_csv("datasets/titanic3.csv")
df_titanic #rows with int indexes and cols as string labels(indexes)...
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df_imdb=pd.read_csv("datasets/imdb.csv")
df_imdb
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
#PYTHON Dictionary Vs Pandas DataFrames....
dict={
    "name":'Maida',
    "Age": 26,
    "Address":"Sialkot",
    "Cell":12345678,
    "BG": "A+"
}
dict
# Out:
# {'name': 'Maida',
#  'Age': 26,
#  'Address': 'Sialkot',
#  'Cell': 12345678,
#  'BG': 'A+'}

# %%
people={
    "name":["Maida", "Asra", "Amna", "Shumaila"],
    "Age": [26, 24, 27, 25],
    "Address":["Sialkot", "Sialkot", "Lahore", "VEhari"],
    "Cell":[30012345678, 30112345678, 30212345678, 30312345678],
    "BG": ["A+", "B+", "O+", "A+"]
}
people
# Out:
# {'name': ['Maida', 'Asra', 'Amna', 'Shumaila'],
#  'Age': [26, 24, 27, 25],
#  'Address': ['Sialkot', 'Sialkot', 'Lahore', 'VEhari'],
#  'Cell': [30012345678, 30112345678, 30212345678, 30312345678],
#  'BG': ['A+', 'B+', 'O+', 'A+']}

# %%
df_people=pd.read_csv("datasets/people.csv")
df_people
# Out:
#       name   age     address      cell   bg
# 0     Rauf    52      Lahore   321-123   B+
# 1     Arif    51     Karachi   320-431   A-
# 2     Maaz    26      Lahore   321-478   B+
# 3   Hadeed    22   Islamabad   324-446   O-
# 4  Mujahid    18       Kakul   321-967   A-
# 5    Mohid    17     Karachi   320-678   B+

# %%
l1=people["name"] #dict returns a list of values related to a key given
print(l1, type(l1))
# Out:
# ['Maida', 'Asra', 'Amna', 'Shumaila'] <class 'list'>

# %%
ser= df_people['name']
print(ser, type(ser))
# Out:
# 0       Rauf
# 1       Arif
# 2       Maaz
# 3     Hadeed
# 4    Mujahid
# 5      Mohid
# Name: name, dtype: object <class 'pandas.core.series.Series'>

# %%
#CHANGING ATTRIBUTES OF DATAFRAME....
df_covid=pd.read_csv("datasets/covid-data.csv")
df_covid #ellipses in data first and last 10 cols are being displayed only...
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 151080      ZWE    Africa     Zimbabwe  2021-12-26     204351.0      605.0
# 151081      ZWE    Africa     Zimbabwe  2021-12-27     205449.0     1098.0
# 151082      ZWE    Africa     Zimbabwe  2021-12-28     207548.0     2099.0
# 151083      ZWE    Africa     Zimbabwe  2021-12-29     207548.0        0.0
# 151084      ZWE    Africa     Zimbabwe  2021-12-30     211728.0     4180.0
#
# ...

# %%
pd.get_option("display.max_columns")
# Out:
# 20

# %%
pd.set_option("display.max_columns", 67) #no ellipses all the cols are being displayed now

# %%
df_covid
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 151080      ZWE    Africa     Zimbabwe  2021-12-26     204351.0      605.0
# 151081      ZWE    Africa     Zimbabwe  2021-12-27     205449.0     1098.0
# 151082      ZWE    Africa     Zimbabwe  2021-12-28     207548.0     2099.0
# 151083      ZWE    Africa     Zimbabwe  2021-12-29     207548.0        0.0
# 151084      ZWE    Africa     Zimbabwe  2021-12-30     211728.0     4180.0
#
# ...

# %%
pd.get_option("display.max_rows")
# Out:
# 100

# %%
pd.set_option("display.max_rows", 100) #now 100 rows are being displayed

# %%
df_covid
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 151080      ZWE    Africa     Zimbabwe  2021-12-26     204351.0      605.0
# 151081      ZWE    Africa     Zimbabwe  2021-12-27     205449.0     1098.0
# 151082      ZWE    Africa     Zimbabwe  2021-12-28     207548.0     2099.0
# 151083      ZWE    Africa     Zimbabwe  2021-12-29     207548.0        0.0
# 151084      ZWE    Africa     Zimbabwe  2021-12-30     211728.0     4180.0
#
# ...

# %%
#change number of characters in a specific column...
df_imdb
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
pd.get_option("display.max_colwidth")
# Out:
# 50

# %%
pd.set_option("display.max_colwidth", 200)

# %%
df_imdb
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
#SETTING ALL OPTION BACK TO DEFAULT 
pd.reset_option('all')
# Out:
# C:\Users\ASCC\anaconda3\lib\site-packages\pandas\_config\config.py:653: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead.
#   warnings.warn(d.msg, FutureWarning)
# C:\Users\ASCC\anaconda3\lib\site-packages\pandas\_config\config.py:653: FutureWarning:
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.
#
#   warnings.warn(d.msg, FutureWarning)
