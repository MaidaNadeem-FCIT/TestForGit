# %%
#DATA VISUALIZATION PART 1....
import numpy as np
from matplotlib import pyplot as plt

# %%
dir(plt)
# Out:
# ['Annotation',
#  'Arrow',
#  'Artist',
#  'AutoLocator',
#  'Axes',
#  'Button',
#  'Circle',
#  'Figure',
#  'FigureCanvasBase',
#  'FixedFormatter',
#  'FixedLocator',
#  'FormatStrFormatter',
#  'Formatter',
#  'FuncFormatter',
#  'GridSpec',
#  'IndexLocator',
#  'Line2D',
#  'LinearLocator',
#  'Locator',
#  'LogFormatter',
#  'LogFormatterExponent',
#  'LogFormatterMathtext',
#  'LogLocator',
#  'MaxNLocator',
#  'MouseButton',
#  'MultipleLocator',
#  'Normalize',
#  'NullFormatter',
#  'NullLocator',
#  'Number',
#  'PolarAxes',
#  'Polygon',
#  'Rectangle',
#  'ScalarFormatter',
#  'Slider',
#  'Subplot',
#  'SubplotSpec',
#  'Text',
#  'TickHelper',
#  'Widget',
#  '_INSTALL_FIG_OBSERVER',
#  '_IP_REGISTERED',
#  '_IoffContext',
#  '_IonContext',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_api',
#  '_auto_draw_if_interactive',
#  '_backend_mod',
#  '_copy_docstring_and_deprecators',
# ...

# %%
#TWO STATES TWO PLOT DATA FOR VISULATIZATIONSS...
# 1. STATEFULL APPROACH....
x=np.linspace(-2,2,20)
y=x**3
plt.plot(x,y)

# %%
# 2. STATELESS APPROACH (OBJECT ORIENTED APPROACH)....
fig=plt.figure()
ax=fig.add_subplot()
ax.plot(x,y)  #recommended approach and used in learning here

# %%
# OR STATELESS WITH...
fig, ax= plt.subplots() # same as above two separate statements for "fig=plt.figure()" and "ax=fig.add_subplot()"
ax.plot(x,y)

# %%
# PLOT#1 ----> LINE CHART....
chemical_exports = [0.810, 0.831, 0.895, 0.91, 0.915, 0.926, 0.945, 0.931, 0.919, 0.921, 0.920, 0.919]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
fig=plt.figure()
ax=fig.add_subplot()
ax.plot(years,chemical_exports)

# %%
# ENHANCE GRAPH
# 1. ADD TITLE...
fig=plt.figure()
ax=fig.add_subplot()
ax.plot(years,chemical_exports)


#adding title...
plt.title("Chemical Exports of Last 12 Years")
# Out:
# Text(0.5, 1.0, 'Chemical Exports of Last 12 Years')

# %%
# 2. ADD X/Y LABELS...
fig=plt.figure()
ax=fig.add_subplot()
ax.plot(years,chemical_exports)



# adding labels...
ax.set_xlabel("Years")
ax.set_ylabel("Amount (Million US$)")
plt.title("Chemical Exports of Last 12 Years")
# Out:
# Text(0.5, 1.0, 'Chemical Exports of Last 12 Years')

# %%
# 3. MODIFYING TICKS...
fig=plt.figure()
ax=fig.add_subplot()
ax.plot(years,chemical_exports)
ax.set_xlabel("Years")
ax.set_ylabel("Amount (Million US$)")

#modifying ticks..
xvals=np.arange(2011, 2022, 2)
yval=np.linspace(0.80, 0.98, 10)
ax.set_xticks(xvals)
ax.set_yticks(yval)

plt.title("Chemical Exports of Last 12 Years")
# Out:
# Text(0.5, 1.0, 'Chemical Exports of Last 12 Years')

# %%
# 4. MULTIPLE LINES IN A GRAPH...

#DATA....
chemical_exports = [0.810, 0.831, 0.895, 0.91, 0.915, 0.926, 0.945, 0.931, 0.919, 0.921, 0.920, 0.919]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
medicine_exports = [0.791, 0.818, 0.832, 0.816, 0.840, 0.833, 0.835, 0.838, 0.842, 0.910, 0.930, 0.940]

#FIGURE AND PLOT
fig=plt.figure()
ax=fig.add_subplot()

#multiple line plots...
ax.plot(years,chemical_exports)
ax.plot(years,medicine_exports)

# adding labels...
ax.set_xlabel("Years")
ax.set_ylabel("Amount (Million US$)")

#modifying ticks..
xvals=np.arange(2011, 2022, 2)
yval=np.linspace(0.80, 0.98, 10)
ax.set_xticks(xvals)
ax.set_yticks(yval)

#adding title...
plt.title("Chemical Exports of Last 12 Years")
# Out:
# Text(0.5, 1.0, 'Chemical Exports of Last 12 Years')

# %%
# 5. ADD LEGEND IN MULTIPLOT  (option 1)

#DATA....
chemical_exports = [0.810, 0.831, 0.895, 0.91, 0.915, 0.926, 0.945, 0.931, 0.919, 0.921, 0.920, 0.919]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
medicine_exports = [0.791, 0.818, 0.832, 0.816, 0.840, 0.833, 0.835, 0.838, 0.842, 0.910, 0.930, 0.940]

#FIGURE AND PLOT
fig=plt.figure()
ax=fig.add_subplot()

#multiple line plots...
ax.plot(years,chemical_exports)
ax.plot(years,medicine_exports)

# adding labels...
ax.set_xlabel("Years")
ax.set_ylabel("Amount (Million US$)")

#modifying ticks..
xvals=np.arange(2011, 2022, 2)
yval=np.linspace(0.80, 0.98, 10)
ax.set_xticks(xvals)
ax.set_yticks(yval)

#adding title...
plt.title("Chemical Exports of Last 12 Years")

#adding legend...
plt.legend(["Chemical","Medicine"])  #not good if we change the order of plot in above lines

# %%
# 5. ADD LEGEND IN MULTIPLOT  (option 2)

#DATA....
chemical_exports = [0.810, 0.831, 0.895, 0.91, 0.915, 0.926, 0.945, 0.931, 0.919, 0.921, 0.920, 0.919]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
medicine_exports = [0.791, 0.818, 0.832, 0.816, 0.840, 0.833, 0.835, 0.838, 0.842, 0.910, 0.930, 0.940]

#FIGURE AND PLOT
fig=plt.figure()
ax=fig.add_subplot()

#multiple line plots  with legend names...
ax.plot(years,chemical_exports, label="Chemical")
ax.plot(years,medicine_exports, label="Medicine")

# adding labels...
ax.set_xlabel("Years")
ax.set_ylabel("Amount (Million US$)")

#modifying ticks..
xvals=np.arange(2011, 2022, 2)
yval=np.linspace(0.80, 0.98, 10)
ax.set_xticks(xvals)
ax.set_yticks(yval)

#adding title...
plt.title("Chemical Exports of Last 12 Years")

#calling legend
#ax.legend(loc='upper left')
#ax.legend(loc='upper right')
#ax.legend(loc='lower left')   #bad location
#ax.legend(loc='lower right')
ax.legend(loc='best')

# %%
# 6. ADD MARKERS.....

#DATA....
chemical_exports = [0.810, 0.831, 0.895, 0.91, 0.915, 0.926, 0.945, 0.931, 0.919, 0.921, 0.920, 0.919]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
medicine_exports = [0.791, 0.818, 0.832, 0.816, 0.840, 0.833, 0.835, 0.838, 0.842, 0.910, 0.930, 0.940]

#FIGURE AND PLOT
fig=plt.figure()
ax=fig.add_subplot()

#multiple line plots  with MARKERS names...
ax.plot(years,chemical_exports, label="Chemical", marker='o')
ax.plot(years,medicine_exports, label="Medicine", marker='x')

# adding labels...
ax.set_xlabel("Years")
ax.set_ylabel("Amount (Million US$)")

#modifying ticks..
xvals=np.arange(2011, 2022, 2)
yval=np.linspace(0.80, 0.98, 10)
ax.set_xticks(xvals)
ax.set_yticks(yval)

#adding title...
plt.title("Chemical Exports of Last 12 Years")

#calling legend
ax.legend(loc='best')

# %%
# 7. ADD STYLE IN GRAPH (option 1).....

#DATA....
chemical_exports = [0.810, 0.831, 0.895, 0.91, 0.915, 0.926, 0.945, 0.931, 0.919, 0.921, 0.920, 0.919]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
medicine_exports = [0.791, 0.818, 0.832, 0.816, 0.840, 0.833, 0.835, 0.838, 0.842, 0.910, 0.930, 0.940]

#FIGURE AND PLOT
fig=plt.figure()
ax=fig.add_subplot()

#multiple line plots  with Style Options names...
ax.plot(years,chemical_exports, label="Chemical", marker='o', c='b', ls='--', lw=2)
ax.plot(years,medicine_exports, label="Medicine", marker='x', c='y', ls='-', lw=2)

# adding labels...
ax.set_xlabel("Years")
ax.set_ylabel("Amount (Million US$)")

#modifying ticks..
xvals=np.arange(2011, 2022, 2)
yval=np.linspace(0.80, 0.98, 10)
ax.set_xticks(xvals)
ax.set_yticks(yval)

#adding title...
plt.title("Chemical Exports of Last 12 Years")

#calling legend
ax.legend(loc='best')

# %%
# 7. ADD STYLE IN GRAPH (option 2).....

#DATA....
chemical_exports = [0.810, 0.831, 0.895, 0.91, 0.915, 0.926, 0.945, 0.931, 0.919, 0.921, 0.920, 0.919]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
medicine_exports = [0.791, 0.818, 0.832, 0.816, 0.840, 0.833, 0.835, 0.838, 0.842, 0.910, 0.930, 0.940]

#FIGURE AND PLOT
fig=plt.figure()
ax=fig.add_subplot()

#multiple line plots  with Style Format String names...
ax.plot(years,chemical_exports, 'o-g', label="Chemical")
ax.plot(years,medicine_exports, 'x-r', label="Medicine")

# adding labels...
ax.set_xlabel("Years")
ax.set_ylabel("Amount (Million US$)")

#modifying ticks..
xvals=np.arange(2011, 2022, 2)
yval=np.linspace(0.80, 0.98, 10)
ax.set_xticks(xvals)
ax.set_yticks(yval)

#adding title...
plt.title("Chemical Exports of Last 12 Years")

#calling legend
ax.legend(loc='best')

# %%
# 8. CHANGE FIGURE SIZE....

#DATA....
chemical_exports = [0.810, 0.831, 0.895, 0.91, 0.915, 0.926, 0.945, 0.931, 0.919, 0.921, 0.920, 0.919]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
medicine_exports = [0.791, 0.818, 0.832, 0.816, 0.840, 0.833, 0.835, 0.838, 0.842, 0.910, 0.930, 0.940]

#FIGURE SIZE
fig=plt.figure(figsize=(12,8))
ax=fig.add_subplot()

#multiple line plots  with Style Options names...
ax.plot(years,chemical_exports, label="Chemical", marker='o', c='b', ls='--', lw=2)
ax.plot(years,medicine_exports, label="Medicine", marker='x', c='y', ls='-', lw=2)

# adding labels...
ax.set_xlabel("Years")
ax.set_ylabel("Amount (Million US$)")

#modifying ticks..
xvals=np.arange(2011, 2022, 2)
yval=np.linspace(0.80, 0.98, 10)
ax.set_xticks(xvals)
ax.set_yticks(yval)

#adding title...
plt.title("Chemical Exports of Last 12 Years")

#calling legend
ax.legend(loc='best')

# %%
# 9. ADD Annotation....

#DATA....
chemical_exports = [0.810, 0.831, 0.895, 0.91, 0.915, 0.926, 0.945, 0.931, 0.919, 0.921, 0.920, 0.919]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
medicine_exports = [0.791, 0.818, 0.832, 0.816, 0.840, 0.833, 0.835, 0.838, 0.842, 0.910, 0.930, 0.940]

#FIGURE SIZE
fig=plt.figure(figsize=(6,6))
ax=fig.add_subplot()

#multiple line plots  with Style Options names...
ax.plot(years,chemical_exports, label="Chemical", marker='o', c='b', ls='--', lw=2)
ax.plot(years,medicine_exports, label="Medicine", marker='x', c='y', ls='-', lw=2)

# adding labels...
ax.set_xlabel("Years")
ax.set_ylabel("Amount (Million US$)")

#modifying ticks..
xvals=np.arange(2011, 2022, 2)
yval=np.linspace(0.80, 0.98, 10)
ax.set_xticks(xvals)
ax.set_yticks(yval)

#adding title...
plt.title("Chemical Exports of Last 12 Years")

#ADDING ANNOTATION...
plt.annotate("Peak of Chemicals", xy=(2016,0.95))

#calling legend
ax.legend(loc='best')

#FORM GRID....
plt.grid(True)

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
#10. BUILT-IN STYLES OG GRAPH....

#DATA....
chemical_exports = [0.810, 0.831, 0.895, 0.91, 0.915, 0.926, 0.945, 0.931, 0.919, 0.921, 0.920, 0.919]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
medicine_exports = [0.791, 0.818, 0.832, 0.816, 0.840, 0.833, 0.835, 0.838, 0.842, 0.910, 0.930, 0.940]

#FIGURE SIZE
fig=plt.figure(figsize=(6,6))
ax=fig.add_subplot()

#multiple line plots  with Style Options names...
ax.plot(years,chemical_exports, label="Chemical", marker='o', c='b', ls='--', lw=2)
ax.plot(years,medicine_exports, label="Medicine", marker='x', c='y', ls='-', lw=2)

# adding labels...
ax.set_xlabel("Years")
ax.set_ylabel("Amount (Million US$)")

#modifying ticks..
xvals=np.arange(2011, 2022, 2)
yval=np.linspace(0.80, 0.98, 10)
ax.set_xticks(xvals)
ax.set_yticks(yval)

#adding title...
plt.title("Chemical Exports of Last 12 Years")

#ADDING ANNOTATION...
plt.annotate("Peak of Chemicals", xy=(2016,0.95))

#calling legend
ax.legend(loc='best')

#FORM GRID....
plt.grid(True)

#FROM BUILT-IN STYLES....
#plt.style.use('ggplot')
#plt.style.use('grayscale')
#plt.style.use('classic')
plt.style.use('default')

# %%
#11.SAVE GRAPH....

#DATA....
chemical_exports = [0.810, 0.831, 0.895, 0.91, 0.915, 0.926, 0.945, 0.931, 0.919, 0.921, 0.920, 0.919]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
medicine_exports = [0.791, 0.818, 0.832, 0.816, 0.840, 0.833, 0.835, 0.838, 0.842, 0.910, 0.930, 0.940]

#FIGURE SIZE
fig=plt.figure(figsize=(6,6))
ax=fig.add_subplot()

#multiple line plots  with Style Options names...
ax.plot(years,chemical_exports, label="Chemical", marker='o', c='b', ls='--', lw=2)
ax.plot(years,medicine_exports, label="Medicine", marker='x', c='y', ls='-', lw=2)

# adding labels...
ax.set_xlabel("Years")
ax.set_ylabel("Amount (Million US$)")

#modifying ticks..
xvals=np.arange(2011, 2022, 2)
yval=np.linspace(0.80, 0.98, 10)
ax.set_xticks(xvals)
ax.set_yticks(yval)

#adding title...
plt.title("Chemical Exports of Last 12 Years")

#ADDING ANNOTATION...
plt.annotate("Peak of Chemicals", xy=(2016,0.95))

#calling legend
ax.legend(loc='best')

#FORM GRID....
plt.grid(True)

#FROM BUILT-IN STYLES....
plt.style.use('default')

#SAVE graph...
plt.savefig("MyFirstLineChart.png")

# %%
# 12. SUBPLOTS....
fig, ax = plt.subplots(nrows=2 , ncols=2)
ax
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
fig, ax = plt.subplots(nrows=2 , ncols=1)
ax
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
fig, ax = plt.subplots(nrows=1 , ncols=2)
ax
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
# 12. Multi Graphs in Multiple Axes....
#DATA....
chemical_exports = [0.810, 0.831, 0.895, 0.91, 0.915, 0.926, 0.945, 0.931, 0.919, 0.921, 0.920, 0.919]
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
medicine_exports = [0.791, 0.818, 0.832, 0.816, 0.840, 0.833, 0.835, 0.838, 0.842, 0.910, 0.930, 0.940]

#FIGURE SIZE
fig, (ax1, ax2)=plt.subplots(nrows=2, ncols=1)

#multiple line plots  with Style Options names...
ax1.plot(years,chemical_exports, label="Chemical", marker='o', c='b', ls='--', lw=2)
plt.title("Chemical Exports of Last 12 Years")
ax1.set_xlabel("Years")
ax1.set_ylabel("Amount (Million Rs.)")

ax2.plot(years,medicine_exports, label="Medicine", marker='x', c='y', ls='-', lw=2)
plt.title("Medicine Exports of Last 12 Years")
ax2.set_xlabel("Years")
ax2.set_ylabel("Amount (Million Rs.)")

plt.tight_layout()
